# %%
from vae import VAETrainer
from ae import AETrainer
from svdd import SVDDTrainer
from datasets import TrainLoader, TestLoader

import sys



from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA

import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import os
import argparse

from tensorflow import keras

# %%
from main import train

# %%
config = [
    [32, 3, 2],
    [64, 3, 2],
    [128, 3, 2],
]

model = train(modelName='svdd', source='../Datasets/datasets-00/', batch_size=16, 
              config=config, latent_dim=16, lr=0.0001, epochs=25, objective='one-class', ae_epochs=100,
              nu=0.02, gamma=0.1)
# Out:
# 2 are Found: ['../Datasets/datasets-00//train//Running', '../Datasets/datasets-00//train//Walking']
# Loading Running........
# --------------------------------
# Loading Walking........
# --------------------------------
# INFO:root:Starting Pretraining...
# Epoch 1/100
# 62/62 [==============================] - 3s 33ms/step - loss: 105.7420
# Epoch 2/100
# 62/62 [==============================] - 2s 33ms/step - loss: 49.6040
# Epoch 3/100
# 62/62 [==============================] - 2s 33ms/step - loss: 49.0937
# Epoch 4/100
# 62/62 [==============================] - 2s 33ms/step - loss: 48.7031
# Epoch 5/100
# 62/62 [==============================] - 2s 33ms/step - loss: 48.4483
# Epoch 6/100
# 62/62 [==============================] - 2s 33ms/step - loss: 48.2860
# Epoch 7/100
# 62/62 [==============================] - 2s 33ms/step - loss: 48.1808
# Epoch 8/100
# 62/62 [==============================] - 2s 33ms/step - loss: 48.0650
# Epoch 9/100
# ...
