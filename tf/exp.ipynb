# %%
from vae import VAETrainer
from ae import AETrainer
from svdd import SVDDTrainer
from datasets import TrainLoader, TestLoader

import sys



from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA

import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import os
import argparse

from tensorflow import keras

# %%
from main import train

# %%
config = [
    [32, 3, 2],
    [64, 3, 2],
    [128, 3, 2],
]

model = train(modelName='isoforest', source='../Datasets/datasets-00/', batch_size=16, 
              config=config, latent_dim=16, lr=0.0001, epochs=20, objective='one-class', ae_epochs=10,
              nu=0.02, gamma=0.1)
# Out:
# 2 are Found: ['../Datasets/datasets-00//train//Running', '../Datasets/datasets-00//train//Walking']
# Loading Running........
# --------------------------------
# Loading Walking........
# --------------------------------
